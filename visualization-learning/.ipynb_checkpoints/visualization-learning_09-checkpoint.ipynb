# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

df = pd.read_csv('../data/body.csv')
df
# Out:
#      Number  Height  Weight
# 0         1   176.0    85.2
# 1         2   175.3    67.7
# 2         3   168.6    75.2
# 3         4   168.1    67.1
# 4         5   175.3    63.0
# ..      ...     ...     ...
# 995     996   171.8    68.2
# 996     997   171.5    75.6
# 997     998   177.9    66.5
# 998     999   174.4    72.0
# 999    1000   173.5    77.4
#
# [1000 rows x 3 columns]

# %%
df.plot(kind='scatter', x='Height', y='Weight')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
sns.lmplot(data=df, x='Height', y='Weight') # lmplot : 회귀선 생성
