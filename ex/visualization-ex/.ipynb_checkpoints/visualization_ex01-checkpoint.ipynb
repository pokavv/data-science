# %%
# %matplotlib inline
import pandas as pd

df = pd.read_csv('../../data/gdp.csv', index_col = 0)

# %%
columns = df.columns

country = ['Korea', 'Germany', 'USA', 'England', 'UK', 'United', 'China', 'Japan']
for name in country:
    print(columns[columns.str.contains(name)])
# Out:
# Index(['Korea_Rep'], dtype='object')
# Index(['Germany'], dtype='object')
# Index([], dtype='object')
# Index([], dtype='object')
# Index([], dtype='object')
# Index(['United Arab Emirates', 'United_Kingdom', 'United_States'], dtype='object')
# Index(['China', 'Hong Kong SAR, China', 'Macao SAR, China'], dtype='object')
# Index(['Japan'], dtype='object')

# %%
df.plot(y = ["Korea_Rep", "United_States", "United_Kingdom", "Germany", "China", "Japan"])
# Out:
# <AxesSubplot:>
