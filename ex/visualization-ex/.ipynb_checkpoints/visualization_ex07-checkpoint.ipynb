# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'NanumGothic' # set font (for Hangul output in the dataset)
plt.rcParams['axes.unicode_minus'] = False # set no use unicode minus
df = pd.read_csv('../../data/subway.csv', index_col=0)
df
# Out:
#      station     in    out
# line
# 중앙선       지평     37     28
# 중앙선       용문   2064   2103
# 중앙선       원덕    375    357
# 중앙선       양평   4338   4378
# 중앙선       오빈    321    321
# ...      ...    ...    ...
# 1호선     종로5가  31245  30678
# 1호선     종로3가  38099  36928
# 1호선       종각  52310  50088
# 1호선       시청  29150  29043
# 1호선      서울역  58391  54356
#
# [591 rows x 3 columns]

# %%
df['in'].sort_index().plot()
# Out:
# <AxesSubplot:xlabel='line'>

# %%
sns.kdeplot(df['in'])
# Out:
# <AxesSubplot:xlabel='in', ylabel='Density'>
